# %% [markdown]
# # NOTES

# %% [markdown]
# - Applying `normalize_subset` to all records that contain `"(?i)microsoft|msft"` - i.e., a group of records that almost certainly all belong to MSFT - the algorithm works. This implies that the issue is indeed with the subgraph creation. I.e., the `"microsoft"` subgraph is being linked to other companies. Most likely, this is because there are 1 or 2 records with, e.g., `{"issuer_name": "microsoft", "cusip": apple's cusip}`. We

# %% [markdown]
# # Main

# %%
import polars as pl
from record_consolidation.graphs import (
    unconsolidated_df_to_subgraphs,
    _extract_canonicals_from_subgraph,
)
from record_consolidation.subgraph_post_processing.specific_algs.split_high_betweenness import (
    split_subgraph_where_necessary,
)
import networkx as nx

# %%
# votes: pl.DataFrame = access_db_table("raw_output", "votes")
votes: pl.DataFrame = pl.read_parquet("raw_votes.parquet")
COMPANY_COLS = pl.col(["issuer_name", "cusip", "isin", "figi"])
MEETING_COLS = pl.col(["issuer_name", "meeting_date", "cusip", "isin", "figi"])

# %%
def ps(subgraph: nx.Graph) -> None:
    for x in subgraph.nodes.data():
        print(x)

# %%
from typing import Iterable
from warnings import warn


def extract_specific_name_subgraph(
    connected_subgs: Iterable[nx.Graph], name: str
) -> nx.Graph:
    collected: list[nx.Graph] = []
    for subg in connected_subgs:
        for n in subg.nodes.data():
            if name.lower() in (n[0]).lower():
                collected.append(subg)
    collected = set(collected)
    if len(collected) == 0:
        raise ValueError(f"Could not find {name=} in connected_subgs.")
    if len(collected) > 1:
        alert_str = f"{len(collected)} subgraphs have {name=}.\n{[len(subg.nodes) for subg in collected]=}"
        warn(alert_str)
        return max(collected, key=lambda g: len(g.nodes))

        # raise ValueError(alert_str)
    return tuple(collected)[0]

# %% [markdown]
# # Extract SubGraphs

# %% [markdown]
# ## Post Processing

# %%
post_processed_subgraphs = list(
    unconsolidated_df_to_subgraphs(
        votes.select(COMPANY_COLS),  # .head(100),
        weight_edges=True,
        connected_subgraphs_postprocessor=split_subgraph_where_necessary,
    )
)

# %%
cvx = extract_specific_name_subgraph(post_processed_subgraphs, "CHEVRON")
# Out:
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_40657/942150125.py:18: UserWarning: 2 subgraphs have name='CHEVRON'.
# [len(subg.nodes) for subg in collected]=[17, 1]
#   warn(alert_str)

# %%
ps(cvx)
# Out:
# ('Chevron', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corposration', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP', {'field': 'issuer_name', 'count': 21})
# ('Chevron Corp.', {'field': 'issuer_name', 'count': 4})
# ('Chevron Corpoation', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP NEW COM', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON', {'field': 'issuer_name', 'count': 2})
# ('BBG000K4ND22', {'field': 'figi', 'count': 5})
# ('Chevron Corp (CVX)', {'field': 'issuer_name', 'count': 1})
# ('Chrvron Corporation', {'field': 'issuer_name', 'count': 1})
# ('US1667641005', {'field': 'isin', 'count': 1227})
# ('CHEVRON CORPORATION', {'field': 'issuer_name', 'count': 1034})
# ('CHEVRON CORP NEW', {'field': 'issuer_name', 'count': 2})
# ('CVX', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corp', {'field': 'issuer_name', 'count': 8})
# ('166764100', {'field': 'cusip', 'count': 1818})
# ('BBG001S67ZC5', {'field': 'figi', 'count': 2})

# %%
msft_subgraph = extract_specific_name_subgraph(post_processed_subgraphs, "microsoft")
mcds_subgraph = extract_specific_name_subgraph(post_processed_subgraphs, "mcdonald")
jpm_subgraph = extract_specific_name_subgraph(post_processed_subgraphs, "jpmorgan")
# Out:
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_35385/942150125.py:18: UserWarning: 3 subgraphs have name='mcdonald'.
# [len(subg.nodes) for subg in collected]=[2, 1, 27]
#   warn(alert_str)
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_35385/942150125.py:18: UserWarning: 2 subgraphs have name='jpmorgan'.
# [len(subg.nodes) for subg in collected]=[1, 25]
#   warn(alert_str)

# %%
ps(jpm_subgraph)
# Out:
# ('JP MORGAN CHASE & CO', {'field': 'issuer_name', 'count': 1})
# ('JPMORGAN CHASE  CO.', {'field': 'issuer_name', 'count': 80})
# ('JPMorgan Chase & CO.', {'field': 'issuer_name', 'count': 20})
# ('JPMORGAN CHASE AND CO.', {'field': 'issuer_name', 'count': 1})
# ('JP MORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1})
# ('JPMorgan Chase', {'field': 'issuer_name', 'count': 7})
# ('BBG000DMBXR2', {'field': 'figi', 'count': 23})
# ('US46625H1005', {'field': 'isin', 'count': 1965})
# ('JP MORGAN CHASE & CO ', {'field': 'issuer_name', 'count': 2})
# ('46625h100', {'field': 'cusip', 'count': 4})
# ('JPMORGAN CHASE &amp; CO.', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1324})
# ('JP Morgan', {'field': 'issuer_name', 'count': 1})
# ('JP Morgan Chase & Co', {'field': 'issuer_name', 'count': 7})
# ('JPMORGAN CHASE and CO.', {'field': 'issuer_name', 'count': 27})
# ('JPMorgan Chase & Co (JPM)', {'field': 'issuer_name', 'count': 1})
# ('46625H100', {'field': 'cusip', 'count': 2639})
# ('JPMorgan Chase & Co.', {'field': 'issuer_name', 'count': 1151})
# ('JPMORGAN CHASE & CO. COM', {'field': 'issuer_name', 'count': 1})
# ('JP Morgan Chase & Co.', {'field': 'issuer_name', 'count': 7})
# ('BBG001S8CRC3', {'field': 'figi', 'count': 1})
# ('JPMorgan Chase & Co', {'field': 'issuer_name', 'count': 11})
# ('JPMORGAN CHASE & CO', {'field': 'issuer_name', 'count': 9})
# ('JPM', {'field': 'issuer_name', 'count': 2})
# ('JP MORGAN CHASE', {'field': 'issuer_name', 'count': 1})

# %% [markdown]
# ## No PostProcessing

# %%
subgraphs = list(
    unconsolidated_df_to_subgraphs(
        votes.select(COMPANY_COLS),
        weight_edges=True,
        connected_subgraphs_postprocessor=None,
    )
)

# %% [markdown]
# ## Compare the two

# %%
erroneously_linked_cos = [
    "microsoft",
    "chevron",
    "jpmorgan",
    "starbucks",
    "proctor",
]
for co in erroneously_linked_cos:
    post_processed = extract_specific_name_subgraph(post_processed_subgraphs, name=co)
    unprocessed = extract_specific_name_subgraph(subgraphs, name=co)

    print("-" * 120)

    print("UNPROCESSED:\n")
    ps(unprocessed)

    print("PROCESSED:\n")
    ps(post_processed)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# UNPROCESSED:
#
# ('Duke Energy', {'field': 'issuer_name', 'count': 4})
# ('DUKE ENERGY CORP', {'field': 'issuer_name', 'count': 1})
# ('GE HealthCare Technologies Inc', {'field': 'issuer_name', 'count': 1})
# ('MICROSOFT CORPORATION COM', {'field': 'issuer_name', 'count': 2})
# ('26441c204', {'field': 'cusip', 'count': 1})
# ('USU3644QAF29', {'field': 'isin', 'count': 1})
# ('Mckesson Corporation', {'field': 'issuer_name', 'count': 5})
# ('594918105', {'field': 'cusip', 'count': 1})
# ('Microsoft Corporation (MSFT)', {'field': 'issuer_name', 'count': 2})
# ('594918104', {'field': 'cusip', 'count': 4698})
# ('Microsoft Corp.', {'field': 'issuer_name', 'count': 60})
# ('MICROSOFT CORP COM', {'field': 'issuer_name', 'count': 1})
# ('GE Healthcare Technologies Inc', {'field': 'issuer_name', 'count': 9})
# ('36266G107', {'field': 'cusip', 'count': 549})
# ('Duke Energy Corp.', {'field': 'issuer_name', 'count': 5})
# ('GE HEALTHCARE TECHNOLOGY', {'field': 'issuer_name', 'count': 1})
# ('MSFT', {'field': 'issuer_name', 'count': 3})
# ('US36266G1076', {'field': 'isin', 'count': 404})
# ('Microsoft Corporation', {'field': 'issuer_name', 'count': 1795})
# ('MICROSOFTCORPORATION', {'field': 'issuer_name', 'count': 2})
# ('Mitsubishi Financial Group', {'field': 'issuer_name', 'count': 1})
# ('Duke Energy Corporation', {'field': 'issuer_name', 'count': 152})
# ('58155Q103', {'field': 'cusip', 'count': 1066})
# ('BBG000BLNPB7', {'field': 'figi', 'count': 6})
# ('DUKE ENERGYCORPORATION', {'field': 'issuer_name', 'count': 1})
# ('MICROSOFT', {'field': 'issuer_name', 'count': 2})
# ('GE HEALTHCARE TECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 330})
# ('BBG000BPH459', {'field': 'figi', 'count': 79})
# ('GE Healthcare Tech', {'field': 'issuer_name', 'count': 1})
# ('26441C204', {'field': 'cusip', 'count': 1201})
# ('US5949181045', {'field': 'isin', 'count': 3197})
# ('Microsoft Annual Meeting', {'field': 'issuer_name', 'count': 1})
# ('MCKESSONCORPORATION', {'field': 'issuer_name', 'count': 2})
# ('GE HEALTHCARE TECHONOLOGIES', {'field': 'issuer_name', 'count': 12})
# ('McKesson Corporation', {'field': 'issuer_name', 'count': 556})
# ('GE HEALTHCARE\nTECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 14})
# ('GE HEALTHCARE', {'field': 'issuer_name', 'count': 1})
# ('GE HEALTHCARETECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 1})
# ('000594918', {'field': 'cusip', 'count': 2})
# ('26441C501', {'field': 'cusip', 'count': 38})
# ('BBG001S5TD05', {'field': 'figi', 'count': 1})
# ('MICROSOFT CORPORATION', {'field': 'issuer_name', 'count': 2555})
# ('MICROSOFT\nCORPORATION', {'field': 'issuer_name', 'count': 64})
# ('US58155Q1031', {'field': 'isin', 'count': 630})
# ('GE Healthcare Technologies', {'field': 'issuer_name', 'count': 2})
# ('MCKESSON\nCORPORATION', {'field': 'issuer_name', 'count': 44})
# ('36266g107', {'field': 'cusip', 'count': 1})
# ('MCKESSON CORP', {'field': 'issuer_name', 'count': 4})
# ('DUKE ENERGY CORPORATION', {'field': 'issuer_name', 'count': 768})
# ('DUKE ENERGY', {'field': 'issuer_name', 'count': 3})
# ('594918103', {'field': 'cusip', 'count': 3})
# ('Microsoft Corp', {'field': 'issuer_name', 'count': 226})
# ('MCKESSON CORPORATION', {'field': 'issuer_name', 'count': 463})
# ('DUKE ENERGY\nCORPORATION', {'field': 'issuer_name', 'count': 39})
# ('Duke Energy Corporation (DUK)', {'field': 'issuer_name', 'count': 1})
# ('GE Healthcare Technologies, Inc.', {'field': 'issuer_name', 'count': 145})
# ('Duke Energy Corporation.', {'field': 'issuer_name', 'count': 264})
# ('BBG01BFR8YV1', {'field': 'figi', 'count': 1})
# ('Microsoft', {'field': 'issuer_name', 'count': 6})
# ('MICROSOFT CORP', {'field': 'issuer_name', 'count': 13})
# ('US26441C2044', {'field': 'isin', 'count': 845})
# ('GE HEALTHCARE TECHNOLOGIES INC', {'field': 'issuer_name', 'count': 2})
# ('GE Healthcare Technologies Inc.', {'field': 'issuer_name', 'count': 7})
# ('GE Healthcare Technologies, Inc. ', {'field': 'issuer_name', 'count': 1})
# ('DUKE ENERGY CORPORATION.', {'field': 'issuer_name', 'count': 1})
# ('GE HEALTHCARE TECHNOLOGIES, INC.', {'field': 'issuer_name', 'count': 1})
# ('DUK', {'field': 'issuer_name', 'count': 1})
# ('GE HealthCare Technologies Inc.', {'field': 'issuer_name', 'count': 26})
# ('Mckesson Corp', {'field': 'issuer_name', 'count': 1})
# ('Duke Energy Corp', {'field': 'issuer_name', 'count': 4})
# ('DUKE ENERGY CORP NEW COM NEW', {'field': 'issuer_name', 'count': 1})
# PROCESSED:
#
# ('MICROSOFT CORPORATION COM', {'field': 'issuer_name', 'count': 2})
# ('594918105', {'field': 'cusip', 'count': 1})
# ('594918104', {'field': 'cusip', 'count': 4698})
# ('Microsoft Corp.', {'field': 'issuer_name', 'count': 60})
# ('MICROSOFT CORP COM', {'field': 'issuer_name', 'count': 1})
# ('MSFT', {'field': 'issuer_name', 'count': 3})
# ('Microsoft Corporation', {'field': 'issuer_name', 'count': 1795})
# ('MICROSOFTCORPORATION', {'field': 'issuer_name', 'count': 2})
# ('Mitsubishi Financial Group', {'field': 'issuer_name', 'count': 1})
# ('MICROSOFT', {'field': 'issuer_name', 'count': 2})
# ('BBG000BPH459', {'field': 'figi', 'count': 79})
# ('US5949181045', {'field': 'isin', 'count': 3197})
# ('Microsoft Annual Meeting', {'field': 'issuer_name', 'count': 1})
# ('000594918', {'field': 'cusip', 'count': 2})
# ('BBG001S5TD05', {'field': 'figi', 'count': 1})
# ('MICROSOFT CORPORATION', {'field': 'issuer_name', 'count': 2555})
# ('MICROSOFT\nCORPORATION', {'field': 'issuer_name', 'count': 64})
# ('Microsoft Corp', {'field': 'issuer_name', 'count': 226})
# ('Microsoft', {'field': 'issuer_name', 'count': 6})
# ('MICROSOFT CORP', {'field': 'issuer_name', 'count': 13})
# ('Microsoft Corporation (MSFT)', {'field': 'issuer_name', 'count': 2})
# ------------------------------------------------------------------------------------------------------------------------
# UNPROCESSED:
#
# ('Chevron', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corposration', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP', {'field': 'issuer_name', 'count': 21})
# ('577081102', {'field': 'cusip', 'count': 176})
# ('277081102', {'field': 'cusip', 'count': 2})
# ('Chevron Corp.', {'field': 'issuer_name', 'count': 4})
# ('Mattel Incorporated', {'field': 'issuer_name', 'count': 1})
# ('Mattel', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corpoation', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP NEW COM', {'field': 'issuer_name', 'count': 1})
# ('Mattel Inc (MAT)', {'field': 'issuer_name', 'count': 2})
# ('CHEVRON', {'field': 'issuer_name', 'count': 2})
# ('BBG000K4ND22', {'field': 'figi', 'count': 5})
# ('US5770811025', {'field': 'isin', 'count': 122})
# ('000166764', {'field': 'cusip', 'count': 1})
# ('Chevron Corp (CVX)', {'field': 'issuer_name', 'count': 1})
# ('Chrvron Corporation', {'field': 'issuer_name', 'count': 1})
# ('US1667641005', {'field': 'isin', 'count': 1227})
# ('CHEVRON CORPORATION', {'field': 'issuer_name', 'count': 1034})
# ('CHEVRON CORP NEW', {'field': 'issuer_name', 'count': 2})
# ('CVX', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corp', {'field': 'issuer_name', 'count': 8})
# ('166764100', {'field': 'cusip', 'count': 1818})
# ('MATTEL, INC.', {'field': 'issuer_name', 'count': 117})
# ('MATTEL, INC', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corporation', {'field': 'issuer_name', 'count': 751})
# ('BBG001S67ZC5', {'field': 'figi', 'count': 2})
# ('Mattel, Inc.', {'field': 'issuer_name', 'count': 56})
# PROCESSED:
#
# ('Chevron', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corposration', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP', {'field': 'issuer_name', 'count': 21})
# ('Chevron Corp.', {'field': 'issuer_name', 'count': 4})
# ('Chevron Corpoation', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON CORP NEW COM', {'field': 'issuer_name', 'count': 1})
# ('CHEVRON', {'field': 'issuer_name', 'count': 2})
# ('BBG000K4ND22', {'field': 'figi', 'count': 5})
# ('Chevron Corp (CVX)', {'field': 'issuer_name', 'count': 1})
# ('Chrvron Corporation', {'field': 'issuer_name', 'count': 1})
# ('US1667641005', {'field': 'isin', 'count': 1227})
# ('CHEVRON CORPORATION', {'field': 'issuer_name', 'count': 1034})
# ('CHEVRON CORP NEW', {'field': 'issuer_name', 'count': 2})
# ('CVX', {'field': 'issuer_name', 'count': 1})
# ('Chevron Corp', {'field': 'issuer_name', 'count': 8})
# ('166764100', {'field': 'cusip', 'count': 1818})
# ('BBG001S67ZC5', {'field': 'figi', 'count': 2})
# ------------------------------------------------------------------------------------------------------------------------
# UNPROCESSED:
#
# ('02209S109', {'field': 'cusip', 'count': 1})
# ('BLACKROCK ', {'field': 'issuer_name', 'count': 1})
# ('09247K101', {'field': 'cusip', 'count': 1})
# ('JPMorgan Chase', {'field': 'issuer_name', 'count': 7})
# ('JPMORGAN CHASE & CO', {'field': 'issuer_name', 'count': 9})
# ('Altria Group, Inc.', {'field': 'issuer_name', 'count': 455})
# ('Blackrock Inc.', {'field': 'issuer_name', 'count': 7})
# ('ALTRIA GROUP', {'field': 'issuer_name', 'count': 2})
# ('JPMorgan Chase & Co (JPM)', {'field': 'issuer_name', 'count': 1})
# ('02209s103', {'field': 'cusip', 'count': 1})
# ('JPMorgan Chase & Co.', {'field': 'issuer_name', 'count': 1151})
# ('ALTRIA CORP', {'field': 'issuer_name', 'count': 1})
# ('Pfizer INC', {'field': 'issuer_name', 'count': 3})
# ('JP MORGAN CHASE & CO ', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE &amp; CO.', {'field': 'issuer_name', 'count': 2})
# ('BLK', {'field': 'issuer_name', 'count': 1})
# ('BlackRock, Inc.', {'field': 'issuer_name', 'count': 456})
# ('JPMORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1324})
# ('ALTRIA GROUP INC COM', {'field': 'issuer_name', 'count': 1})
# ('JPMorgan Chase & CO.', {'field': 'issuer_name', 'count': 20})
# ('BBG000C2PW58', {'field': 'figi', 'count': 1})
# ('ALTRIA GROUP INC', {'field': 'issuer_name', 'count': 1})
# ('US02209S1033', {'field': 'isin', 'count': 546})
# ('JP MORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1})
# ('BlackRock', {'field': 'issuer_name', 'count': 3})
# ('46625h100', {'field': 'cusip', 'count': 4})
# ('Blackrock, Inc.', {'field': 'issuer_name', 'count': 8})
# ('BLACKROCK, INC', {'field': 'issuer_name', 'count': 2})
# ('09247X101', {'field': 'cusip', 'count': 1236})
# ('09247x101', {'field': 'cusip', 'count': 1})
# ('BBG001S8CRC3', {'field': 'figi', 'count': 1})
# ('JPMORGAN CHASE  CO.', {'field': 'issuer_name', 'count': 80})
# ('JP Morgan', {'field': 'issuer_name', 'count': 1})
# ('The Altria Group, Inc.', {'field': 'issuer_name', 'count': 1})
# ('JP MORGAN CHASE', {'field': 'issuer_name', 'count': 1})
# ('US46625H1005', {'field': 'isin', 'count': 1965})
# ('Blackrock', {'field': 'issuer_name', 'count': 22})
# ('JPM', {'field': 'issuer_name', 'count': 2})
# ('BLACKROCK, INC.', {'field': 'issuer_name', 'count': 696})
# ('JPMORGAN CHASE and CO.', {'field': 'issuer_name', 'count': 27})
# ('JP Morgan Chase & Co.', {'field': 'issuer_name', 'count': 7})
# ('ALTRIA', {'field': 'issuer_name', 'count': 1})
# ('Altria Group', {'field': 'issuer_name', 'count': 18})
# ('BlackRock Inc', {'field': 'issuer_name', 'count': 1})
# ('BLACKROCK INC', {'field': 'issuer_name', 'count': 46})
# ('46625H100', {'field': 'cusip', 'count': 2639})
# ('JPMORGAN CHASE AND CO.', {'field': 'issuer_name', 'count': 1})
# ('Altria Group, Inc', {'field': 'issuer_name', 'count': 18})
# ('ALTRIA GROUP, INC', {'field': 'issuer_name', 'count': 3})
# ('US09247X1019', {'field': 'isin', 'count': 851})
# ('JPMorgan Chase & Co', {'field': 'issuer_name', 'count': 11})
# ('Altria Group Inc', {'field': 'issuer_name', 'count': 3})
# ('JP MORGAN CHASE & CO', {'field': 'issuer_name', 'count': 1})
# ('ALTRIA GROUP, INC.', {'field': 'issuer_name', 'count': 429})
# ('Altria Group Inc.', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE & CO. COM', {'field': 'issuer_name', 'count': 1})
# ('JP Morgan Chase & Co', {'field': 'issuer_name', 'count': 7})
# ('02209S103', {'field': 'cusip', 'count': 929})
# ('MO', {'field': 'issuer_name', 'count': 1})
# ('BBG000BP6LJ8', {'field': 'figi', 'count': 1})
# ('BBG000DMBXR2', {'field': 'figi', 'count': 23})
# PROCESSED:
#
# ('JPMorgan Chase', {'field': 'issuer_name', 'count': 7})
# ('JPMORGAN CHASE & CO', {'field': 'issuer_name', 'count': 9})
# ('JPMorgan Chase & Co (JPM)', {'field': 'issuer_name', 'count': 1})
# ('JPMorgan Chase & Co.', {'field': 'issuer_name', 'count': 1151})
# ('JP MORGAN CHASE & CO ', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE &amp; CO.', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1324})
# ('JPMorgan Chase & CO.', {'field': 'issuer_name', 'count': 20})
# ('JP MORGAN CHASE & CO.', {'field': 'issuer_name', 'count': 1})
# ('46625h100', {'field': 'cusip', 'count': 4})
# ('BBG001S8CRC3', {'field': 'figi', 'count': 1})
# ('JPMORGAN CHASE  CO.', {'field': 'issuer_name', 'count': 80})
# ('JP Morgan', {'field': 'issuer_name', 'count': 1})
# ('JP MORGAN CHASE', {'field': 'issuer_name', 'count': 1})
# ('US46625H1005', {'field': 'isin', 'count': 1965})
# ('JPM', {'field': 'issuer_name', 'count': 2})
# ('JPMORGAN CHASE and CO.', {'field': 'issuer_name', 'count': 27})
# ('JP Morgan Chase & Co.', {'field': 'issuer_name', 'count': 7})
# ('46625H100', {'field': 'cusip', 'count': 2639})
# ('JPMORGAN CHASE AND CO.', {'field': 'issuer_name', 'count': 1})
# ('JPMorgan Chase & Co', {'field': 'issuer_name', 'count': 11})
# ('JP MORGAN CHASE & CO', {'field': 'issuer_name', 'count': 1})
# ('JPMORGAN CHASE & CO. COM', {'field': 'issuer_name', 'count': 1})
# ('JP Morgan Chase & Co', {'field': 'issuer_name', 'count': 7})
# ('BBG000DMBXR2', {'field': 'figi', 'count': 23})
# ------------------------------------------------------------------------------------------------------------------------
# UNPROCESSED:
#
# ('THE PROCTER  GAMBLE COMPANY', {'field': 'issuer_name', 'count': 100})
# ('DIS', {'field': 'issuer_name', 'count': 8})
# ('IPG', {'field': 'issuer_name', 'count': 1})
# ('WALT DISNEY CO', {'field': 'issuer_name', 'count': 1})
# ('THE PROCTER AND GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('Procter & Gamble Co.', {'field': 'issuer_name', 'count': 5})
# ('302316102', {'field': 'cusip', 'count': 1})
# ('Walt Disney (DIS)', {'field': 'issuer_name', 'count': 1})
# ('THE INTERPUBLIC\nGROUP OF COMPANIES,\nINC.', {'field': 'issuer_name', 'count': 17})
# ('THE WALT DISNEY COMPANY', {'field': 'issuer_name', 'count': 1408})
# ('US8552441094', {'field': 'isin', 'count': 791})
# ('The Interpublic Group of Companies, Inc.', {'field': 'issuer_name', 'count': 165})
# ('STARBUCKS CORPORATION', {'field': 'issuer_name', 'count': 572})
# ('The Proter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('The Procter & Gamble Co.', {'field': 'issuer_name', 'count': 10})
# ('PROCTER AND GAMBLE CO', {'field': 'issuer_name', 'count': 1})
# ('Starbucks Corporation', {'field': 'issuer_name', 'count': 405})
# ('The Walt Disney Co', {'field': 'issuer_name', 'count': 3})
# ('Walt Disney', {'field': 'issuer_name', 'count': 1})
# ('Walt Disney Company', {'field': 'issuer_name', 'count': 3})
# ('BBG001S5QHF3', {'field': 'figi', 'count': 1})
# ('Walt Disney Company (The)', {'field': 'issuer_name', 'count': 1})
# ('BBG000BH4R78', {'field': 'figi', 'count': 2})
# ('Starbucks Corp.', {'field': 'issuer_name', 'count': 8})
# ('Walt Disney Co/The', {'field': 'issuer_name', 'count': 1})
# ('The Walt Disney Company Trian Group Contested', {'field': 'issuer_name', 'count': 2})
# ('The Walt Disney Company Contested', {'field': 'issuer_name', 'count': 2})
# ('US7427181091', {'field': 'isin', 'count': 1555})
# ('THE PROCTER & GAMBLE\nCOMPANY', {'field': 'issuer_name', 'count': 65})
# ('Procter & Gamble Company (The)', {'field': 'issuer_name', 'count': 2})
# ('The Walt Disney Company', {'field': 'issuer_name', 'count': 1489})
# ('Procter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('PROCTOR AND GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('DISNEY WALT CO', {'field': 'issuer_name', 'count': 2})
# ('THE INTERPUBLIC GROUP OF COMPANIES, INC.', {'field': 'issuer_name', 'count': 203})
# ('THE WALT DISNEY\nCOMPANY', {'field': 'issuer_name', 'count': 12})
# ('BBG001S5V4L9', {'field': 'figi', 'count': 1})
# ('THE PROCTER &amp; GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('The Proctor & Gamble Company', {'field': 'issuer_name', 'count': 4})
# ('The Procter & Gamble Company', {'field': 'issuer_name', 'count': 1001})
# ('Starbucks Corporation (SBUX)', {'field': 'issuer_name', 'count': 1})
# ('INTERPUBLIC GROUP', {'field': 'issuer_name', 'count': 1})
# ('Proctor & Gamble Company', {'field': 'issuer_name', 'count': 100})
# ('PG', {'field': 'issuer_name', 'count': 3})
# ('WALT DISNEY', {'field': 'issuer_name', 'count': 2})
# ('460690100', {'field': 'cusip', 'count': 387})
# ('BBG000BH4R79', {'field': 'figi', 'count': 1})
# ('THE WALT DISNEY CO', {'field': 'issuer_name', 'count': 1})
# ('Proctor Gamble', {'field': 'issuer_name', 'count': 1})
# ('DISNEY WALT CO COM', {'field': 'issuer_name', 'count': 1})
# ('US4606901001', {'field': 'isin', 'count': 294})
# ('000855244', {'field': 'cusip', 'count': 1})
# ('PROCTER AND GAMBLE CO COM', {'field': 'issuer_name', 'count': 1})
# ('Starbucks Corp', {'field': 'issuer_name', 'count': 8})
# ('Proctor & Gamble', {'field': 'issuer_name', 'count': 1})
# ('Walt Disney Co (The)', {'field': 'issuer_name', 'count': 9})
# ('BBG000CTQBF3', {'field': 'figi', 'count': 1})
# ('742718109', {'field': 'cusip', 'count': 2587})
# ('US2546871060', {'field': 'isin', 'count': 2394})
# ('PROCTOR & GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('Interpublic Group Of Cos., Inc.', {'field': 'issuer_name', 'count': 1})
# ('The Walt Disney Corporation', {'field': 'issuer_name', 'count': 1})
# ('Starbucks', {'field': 'issuer_name', 'count': 21})
# ('SBUX', {'field': 'issuer_name', 'count': 3})
# ('STARBUCKS', {'field': 'issuer_name', 'count': 3})
# ('254687106', {'field': 'cusip', 'count': 2890})
# ('Procter & Gamble', {'field': 'issuer_name', 'count': 5})
# ('Walt Disney Co.', {'field': 'issuer_name', 'count': 1})
# ('PROCTER & GAMBLE COMPANY COM', {'field': 'issuer_name', 'count': 2})
# ('Starbucks Corp. ', {'field': 'issuer_name', 'count': 1})
# ('BBG000BR2TH3', {'field': 'figi', 'count': 2})
# ('855244109', {'field': 'cusip', 'count': 1022})
# ('BBG000BLNNV0', {'field': 'figi', 'count': 4})
# ('Z54687106', {'field': 'cusip', 'count': 48})
# ('The Walt Disney Company*', {'field': 'issuer_name', 'count': 1})
# ('PROCTER & GAMBLE CO', {'field': 'issuer_name', 'count': 2})
# ('Procter & Gamble Company', {'field': 'issuer_name', 'count': 25})
# ('STARBUCKS CORP', {'field': 'issuer_name', 'count': 3})
# ('THE PROCTER and GAMBLE COMPANY', {'field': 'issuer_name', 'count': 78})
# ('STARBUCKS\nCORPORATION', {'field': 'issuer_name', 'count': 8})
# ('Walt Disney Co', {'field': 'issuer_name', 'count': 1})
# ('THE PROCTER & GAMBLE COMPANY', {'field': 'issuer_name', 'count': 1186})
# ('THE PROCTER & GAMBLECOMPANY', {'field': 'issuer_name', 'count': 2})
# PROCESSED:
#
# ('Starbucks Corp.', {'field': 'issuer_name', 'count': 8})
# ('BBG000CTQBF3', {'field': 'figi', 'count': 1})
# ('US8552441094', {'field': 'isin', 'count': 791})
# ('STARBUCKS CORP', {'field': 'issuer_name', 'count': 3})
# ('Starbucks Corp. ', {'field': 'issuer_name', 'count': 1})
# ('STARBUCKS CORPORATION', {'field': 'issuer_name', 'count': 572})
# ('855244109', {'field': 'cusip', 'count': 1022})
# ('STARBUCKS\nCORPORATION', {'field': 'issuer_name', 'count': 8})
# ('Starbucks', {'field': 'issuer_name', 'count': 21})
# ('SBUX', {'field': 'issuer_name', 'count': 3})
# ('Starbucks Corporation (SBUX)', {'field': 'issuer_name', 'count': 1})
# ('Starbucks Corp', {'field': 'issuer_name', 'count': 8})
# ('302316102', {'field': 'cusip', 'count': 1})
# ('Starbucks Corporation', {'field': 'issuer_name', 'count': 405})
# ('000855244', {'field': 'cusip', 'count': 1})
# ------------------------------------------------------------------------------------------------------------------------
# UNPROCESSED:
#
# ('THE PROCTER  GAMBLE COMPANY', {'field': 'issuer_name', 'count': 100})
# ('DIS', {'field': 'issuer_name', 'count': 8})
# ('IPG', {'field': 'issuer_name', 'count': 1})
# ('WALT DISNEY CO', {'field': 'issuer_name', 'count': 1})
# ('THE PROCTER AND GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('Procter & Gamble Co.', {'field': 'issuer_name', 'count': 5})
# ('302316102', {'field': 'cusip', 'count': 1})
# ('Walt Disney (DIS)', {'field': 'issuer_name', 'count': 1})
# ('THE INTERPUBLIC\nGROUP OF COMPANIES,\nINC.', {'field': 'issuer_name', 'count': 17})
# ('THE WALT DISNEY COMPANY', {'field': 'issuer_name', 'count': 1408})
# ('US8552441094', {'field': 'isin', 'count': 791})
# ('The Interpublic Group of Companies, Inc.', {'field': 'issuer_name', 'count': 165})
# ('STARBUCKS CORPORATION', {'field': 'issuer_name', 'count': 572})
# ('The Proter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('The Procter & Gamble Co.', {'field': 'issuer_name', 'count': 10})
# ('PROCTER AND GAMBLE CO', {'field': 'issuer_name', 'count': 1})
# ('Starbucks Corporation', {'field': 'issuer_name', 'count': 405})
# ('The Walt Disney Co', {'field': 'issuer_name', 'count': 3})
# ('Walt Disney', {'field': 'issuer_name', 'count': 1})
# ('Walt Disney Company', {'field': 'issuer_name', 'count': 3})
# ('BBG001S5QHF3', {'field': 'figi', 'count': 1})
# ('Walt Disney Company (The)', {'field': 'issuer_name', 'count': 1})
# ('BBG000BH4R78', {'field': 'figi', 'count': 2})
# ('Starbucks Corp.', {'field': 'issuer_name', 'count': 8})
# ('Walt Disney Co/The', {'field': 'issuer_name', 'count': 1})
# ('The Walt Disney Company Trian Group Contested', {'field': 'issuer_name', 'count': 2})
# ('The Walt Disney Company Contested', {'field': 'issuer_name', 'count': 2})
# ('US7427181091', {'field': 'isin', 'count': 1555})
# ('THE PROCTER & GAMBLE\nCOMPANY', {'field': 'issuer_name', 'count': 65})
# ('Procter & Gamble Company (The)', {'field': 'issuer_name', 'count': 2})
# ('The Walt Disney Company', {'field': 'issuer_name', 'count': 1489})
# ('Procter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('PROCTOR AND GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('DISNEY WALT CO', {'field': 'issuer_name', 'count': 2})
# ('THE INTERPUBLIC GROUP OF COMPANIES, INC.', {'field': 'issuer_name', 'count': 203})
# ('THE WALT DISNEY\nCOMPANY', {'field': 'issuer_name', 'count': 12})
# ('BBG001S5V4L9', {'field': 'figi', 'count': 1})
# ('THE PROCTER &amp; GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('The Proctor & Gamble Company', {'field': 'issuer_name', 'count': 4})
# ('The Procter & Gamble Company', {'field': 'issuer_name', 'count': 1001})
# ('Starbucks Corporation (SBUX)', {'field': 'issuer_name', 'count': 1})
# ('INTERPUBLIC GROUP', {'field': 'issuer_name', 'count': 1})
# ('Proctor & Gamble Company', {'field': 'issuer_name', 'count': 100})
# ('PG', {'field': 'issuer_name', 'count': 3})
# ('WALT DISNEY', {'field': 'issuer_name', 'count': 2})
# ('460690100', {'field': 'cusip', 'count': 387})
# ('BBG000BH4R79', {'field': 'figi', 'count': 1})
# ('THE WALT DISNEY CO', {'field': 'issuer_name', 'count': 1})
# ('Proctor Gamble', {'field': 'issuer_name', 'count': 1})
# ('DISNEY WALT CO COM', {'field': 'issuer_name', 'count': 1})
# ('US4606901001', {'field': 'isin', 'count': 294})
# ('000855244', {'field': 'cusip', 'count': 1})
# ('PROCTER AND GAMBLE CO COM', {'field': 'issuer_name', 'count': 1})
# ('Starbucks Corp', {'field': 'issuer_name', 'count': 8})
# ('Proctor & Gamble', {'field': 'issuer_name', 'count': 1})
# ('Walt Disney Co (The)', {'field': 'issuer_name', 'count': 9})
# ('BBG000CTQBF3', {'field': 'figi', 'count': 1})
# ('742718109', {'field': 'cusip', 'count': 2587})
# ('US2546871060', {'field': 'isin', 'count': 2394})
# ('PROCTOR & GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('Interpublic Group Of Cos., Inc.', {'field': 'issuer_name', 'count': 1})
# ('The Walt Disney Corporation', {'field': 'issuer_name', 'count': 1})
# ('Starbucks', {'field': 'issuer_name', 'count': 21})
# ('SBUX', {'field': 'issuer_name', 'count': 3})
# ('STARBUCKS', {'field': 'issuer_name', 'count': 3})
# ('254687106', {'field': 'cusip', 'count': 2890})
# ('Procter & Gamble', {'field': 'issuer_name', 'count': 5})
# ('Walt Disney Co.', {'field': 'issuer_name', 'count': 1})
# ('PROCTER & GAMBLE COMPANY COM', {'field': 'issuer_name', 'count': 2})
# ('Starbucks Corp. ', {'field': 'issuer_name', 'count': 1})
# ('BBG000BR2TH3', {'field': 'figi', 'count': 2})
# ('855244109', {'field': 'cusip', 'count': 1022})
# ('BBG000BLNNV0', {'field': 'figi', 'count': 4})
# ('Z54687106', {'field': 'cusip', 'count': 48})
# ('The Walt Disney Company*', {'field': 'issuer_name', 'count': 1})
# ('PROCTER & GAMBLE CO', {'field': 'issuer_name', 'count': 2})
# ('Procter & Gamble Company', {'field': 'issuer_name', 'count': 25})
# ('STARBUCKS CORP', {'field': 'issuer_name', 'count': 3})
# ('THE PROCTER and GAMBLE COMPANY', {'field': 'issuer_name', 'count': 78})
# ('STARBUCKS\nCORPORATION', {'field': 'issuer_name', 'count': 8})
# ('Walt Disney Co', {'field': 'issuer_name', 'count': 1})
# ('THE PROCTER & GAMBLE COMPANY', {'field': 'issuer_name', 'count': 1186})
# ('THE PROCTER & GAMBLECOMPANY', {'field': 'issuer_name', 'count': 2})
# PROCESSED:
#
# ('THE PROCTER  GAMBLE COMPANY', {'field': 'issuer_name', 'count': 100})
# ('Proctor Gamble', {'field': 'issuer_name', 'count': 1})
# ('742718109', {'field': 'cusip', 'count': 2587})
# ('IPG', {'field': 'issuer_name', 'count': 1})
# ('THE PROCTER AND GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('US7427181091', {'field': 'isin', 'count': 1555})
# ('PROCTOR & GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('Procter & Gamble Co.', {'field': 'issuer_name', 'count': 5})
# ('Procter & Gamble', {'field': 'issuer_name', 'count': 5})
# ('THE PROCTER & GAMBLE\nCOMPANY', {'field': 'issuer_name', 'count': 65})
# ('Procter & Gamble Company (The)', {'field': 'issuer_name', 'count': 2})
# ('PROCTER & GAMBLE COMPANY COM', {'field': 'issuer_name', 'count': 2})
# ('Procter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('PROCTOR AND GAMBLE', {'field': 'issuer_name', 'count': 1})
# ('BBG000BR2TH3', {'field': 'figi', 'count': 2})
# ('BBG001S5V4L9', {'field': 'figi', 'count': 1})
# ('THE PROCTER &amp; GAMBLE COMPANY', {'field': 'issuer_name', 'count': 2})
# ('PROCTER AND GAMBLE CO COM', {'field': 'issuer_name', 'count': 1})
# ('The Proctor & Gamble Company', {'field': 'issuer_name', 'count': 4})
# ('The Proter & Gamble Co', {'field': 'issuer_name', 'count': 1})
# ('The Procter & Gamble Company', {'field': 'issuer_name', 'count': 1001})
# ('Proctor & Gamble', {'field': 'issuer_name', 'count': 1})
# ('PROCTER & GAMBLE CO', {'field': 'issuer_name', 'count': 2})
# ('The Procter & Gamble Co.', {'field': 'issuer_name', 'count': 10})
# ('Procter & Gamble Company', {'field': 'issuer_name', 'count': 25})
# ('THE PROCTER and GAMBLE COMPANY', {'field': 'issuer_name', 'count': 78})
# ('Proctor & Gamble Company', {'field': 'issuer_name', 'count': 100})
# ('PROCTER AND GAMBLE CO', {'field': 'issuer_name', 'count': 1})
# ('PG', {'field': 'issuer_name', 'count': 3})
# ('THE PROCTER & GAMBLECOMPANY', {'field': 'issuer_name', 'count': 2})
# ('THE PROCTER & GAMBLE COMPANY', {'field': 'issuer_name', 'count': 1186})
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_40657/942150125.py:18: UserWarning: 2 subgraphs have name='chevron'.
# [len(subg.nodes) for subg in collected]=[17, 1]
#   warn(alert_str)
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_40657/942150125.py:18: UserWarning: 2 subgraphs have name='chevron'.
# [len(subg.nodes) for subg in collected]=[28, 1]
#   warn(alert_str)
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_40657/942150125.py:18: UserWarning: 2 subgraphs have name='jpmorgan'.
# [len(subg.nodes) for subg in collected]=[25, 1]
#   warn(alert_str)
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_40657/942150125.py:18: UserWarning: 2 subgraphs have name='jpmorgan'.
# [len(subg.nodes) for subg in collected]=[1, 61]
#   warn(alert_str)

# %%
msft_subgraph = extract_specific_name_subgraph(subgraphs, "microsoft")
mcds_subgraph = extract_specific_name_subgraph(subgraphs, "mcdonald")
jpm_subgraph = extract_specific_name_subgraph(subgraphs, "jpmorgan")
# Out:
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_26279/942150125.py:18: UserWarning: 3 subgraphs have name='mcdonald'.
# [len(subg.nodes) for subg in collected]=[1, 2, 54]
#   warn(alert_str)
# /var/folders/z7/gyrmrn1s10zf6k523_6hg_br0000gn/T/ipykernel_26279/942150125.py:18: UserWarning: 2 subgraphs have name='jpmorgan'.
# [len(subg.nodes) for subg in collected]=[1, 61]
#   warn(alert_str)

# %%
ps(msft_subgraph)
# Out:
# ('GE HealthCare Technologies Inc', {'field': 'issuer_name', 'count': 1})
# ('GE Healthcare Technologies', {'field': 'issuer_name', 'count': 2})
# ('GE HEALTHCARE TECHNOLOGIES INC', {'field': 'issuer_name', 'count': 2})
# ('MICROSOFT CORPORATION', {'field': 'issuer_name', 'count': 2555})
# ('DUKE ENERGY CORPORATION', {'field': 'issuer_name', 'count': 768})
# ('BBG000BPH459', {'field': 'figi', 'count': 79})
# ('Duke Energy', {'field': 'issuer_name', 'count': 4})
# ('594918103', {'field': 'cusip', 'count': 3})
# ('DUKE ENERGYCORPORATION', {'field': 'issuer_name', 'count': 1})
# ('DUKE ENERGY\nCORPORATION', {'field': 'issuer_name', 'count': 39})
# ('Microsoft Annual Meeting', {'field': 'issuer_name', 'count': 1})
# ('GE Healthcare Tech', {'field': 'issuer_name', 'count': 1})
# ('Mckesson Corp', {'field': 'issuer_name', 'count': 1})
# ('Microsoft', {'field': 'issuer_name', 'count': 6})
# ('26441c204', {'field': 'cusip', 'count': 1})
# ('BBG001S5TD05', {'field': 'figi', 'count': 1})
# ('USU3644QAF29', {'field': 'isin', 'count': 1})
# ('GE HEALTHCARE TECHONOLOGIES', {'field': 'issuer_name', 'count': 12})
# ('Duke Energy Corp', {'field': 'issuer_name', 'count': 4})
# ('GE HEALTHCARE TECHNOLOGY', {'field': 'issuer_name', 'count': 1})
# ('Microsoft Corporation (MSFT)', {'field': 'issuer_name', 'count': 2})
# ('Duke Energy Corporation.', {'field': 'issuer_name', 'count': 264})
# ('MCKESSON CORP', {'field': 'issuer_name', 'count': 4})
# ('Duke Energy Corporation (DUK)', {'field': 'issuer_name', 'count': 1})
# ('Duke Energy Corporation', {'field': 'issuer_name', 'count': 152})
# ('GE Healthcare Technologies Inc', {'field': 'issuer_name', 'count': 9})
# ('DUKE ENERGY', {'field': 'issuer_name', 'count': 3})
# ('Microsoft Corp.', {'field': 'issuer_name', 'count': 60})
# ('GE HEALTHCARE\nTECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 14})
# ('Duke Energy Corp.', {'field': 'issuer_name', 'count': 5})
# ('Mitsubishi Financial Group', {'field': 'issuer_name', 'count': 1})
# ('DUKE ENERGY CORPORATION.', {'field': 'issuer_name', 'count': 1})
# ('US58155Q1031', {'field': 'isin', 'count': 630})
# ('000594918', {'field': 'cusip', 'count': 2})
# ('MCKESSON CORPORATION', {'field': 'issuer_name', 'count': 463})
# ('MICROSOFT', {'field': 'issuer_name', 'count': 2})
# ('GE Healthcare Technologies, Inc. ', {'field': 'issuer_name', 'count': 1})
# ('GE HealthCare Technologies Inc.', {'field': 'issuer_name', 'count': 26})
# ('BBG000BLNPB7', {'field': 'figi', 'count': 6})
# ('GE HEALTHCARE TECHNOLOGIES, INC.', {'field': 'issuer_name', 'count': 1})
# ('36266G107', {'field': 'cusip', 'count': 549})
# ('58155Q103', {'field': 'cusip', 'count': 1066})
# ('DUKE ENERGY CORP NEW COM NEW', {'field': 'issuer_name', 'count': 1})
# ('MICROSOFT CORP COM', {'field': 'issuer_name', 'count': 1})
# ('Microsoft Corp', {'field': 'issuer_name', 'count': 226})
# ('26441C204', {'field': 'cusip', 'count': 1201})
# ('MSFT', {'field': 'issuer_name', 'count': 3})
# ('DUKE ENERGY CORP', {'field': 'issuer_name', 'count': 1})
# ('36266g107', {'field': 'cusip', 'count': 1})
# ('US5949181045', {'field': 'isin', 'count': 3197})
# ('US36266G1076', {'field': 'isin', 'count': 404})
# ('GE Healthcare Technologies, Inc.', {'field': 'issuer_name', 'count': 145})
# ('594918104', {'field': 'cusip', 'count': 4698})
# ('McKesson Corporation', {'field': 'issuer_name', 'count': 556})
# ('MCKESSONCORPORATION', {'field': 'issuer_name', 'count': 2})
# ('MICROSOFTCORPORATION', {'field': 'issuer_name', 'count': 2})
# ('US26441C2044', {'field': 'isin', 'count': 845})
# ('DUK', {'field': 'issuer_name', 'count': 1})
# ('GE HEALTHCARE TECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 330})
# ('MCKESSON\nCORPORATION', {'field': 'issuer_name', 'count': 44})
# ('GE HEALTHCARE', {'field': 'issuer_name', 'count': 1})
# ('GE HEALTHCARETECHNOLOGIES INC.', {'field': 'issuer_name', 'count': 1})
# ('MICROSOFT CORP', {'field': 'issuer_name', 'count': 13})
# ('Microsoft Corporation', {'field': 'issuer_name', 'count': 1795})
# ('MICROSOFT\nCORPORATION', {'field': 'issuer_name', 'count': 64})
# ('MICROSOFT CORPORATION COM', {'field': 'issuer_name', 'count': 2})
# ('GE Healthcare Technologies Inc.', {'field': 'issuer_name', 'count': 7})
# ('26441C501', {'field': 'cusip', 'count': 38})
# ('Mckesson Corporation', {'field': 'issuer_name', 'count': 5})
# ('BBG01BFR8YV1', {'field': 'figi', 'count': 1})
# ('594918105', {'field': 'cusip', 'count': 1})
